# %% [markdown]
# <a href="https://colab.research.google.com/github/randimaulana70/Pemerograman-Dasar/blob/main/Praktikum%2009.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

city_names = ['Jakarta', 'Bandung', 'Makassar', 'Surabaya', 'Medan', 'Yogyakarta', 'Malang']
population = [10500, 2580, 5896, 2990, 602155, 466755, 746755]
num_airports = [2, 1, 3, 1, 2, 1, 2]

df = pd.DataFrame({
    "City": city_names,
    "Population": population,
    "Airports": num_airports
})

df
# Out:
#          City  Population  Airports
# 0     Jakarta       10500         2
# 1     Bandung        2580         1
# 2    Makassar        5896         3
# 3    Surabaya        2990         1
# 4       Medan      602155         2
# 5  Yogyakarta      466755         1
# 6      Malang      746755         2

# %%
# Ringkasan statistik
df.describe()

# Rata-rata populasi
rata_rata_populasi = df["Population"].mean()
print("Rata-rata populasi:", rata_rata_populasi)

# Modus jumlah bandara
modus_airports = df["Airports"].mode()
print("Modus Airports:", modus_airports)
# Out:
# Rata-rata populasi: 262518.71428571426
# Modus Airports: 0    1
# 1    2
# Name: Airports, dtype: int64

# %%
df["Selisih"] = abs(df["Population"] - df["Population"].mean())
df.sort_values("Selisih").head(1)
# Out:
#          City  Population  Airports        Selisih
# 5  Yogyakarta      466755         1  204236.285714

# %%
num_airports = [2, 1, 3, 1, 2, 1, 2]

# %%
import matplotlib.pyplot as plt

plt.hist(df["Population"])
plt.title("Distribusi Populasi Kota")
plt.xlabel("Population")
plt.ylabel("Frekuensi")
plt.show()

# %%
cor_matrix = df[['Population', 'Airports']].corr()
print("Korelasi:\n", cor_matrix)

cov_matrix = df[['Population', 'Airports']].cov()
print("Kovarian:\n", cov_matrix)
# Out:
# Korelasi:
#              Population  Airports
# Population    1.000000  0.039084
# Airports      0.039084  1.000000
# Kovarian:
#                Population     Airports
# Population  1.093070e+11  9768.071429
# Airports    9.768071e+03     0.571429

# %%
df['Kategori_Bandara'] = df['Airports'].apply(lambda x: 'Banyak' if x >= 3 else 'Sedikit')
df
# Out:
#          City  Population  Airports        Selisih Kategori_Bandara
# 0     Jakarta       10500         2  252018.714286          Sedikit
# 1     Bandung        2580         1  259938.714286          Sedikit
# 2    Makassar        5896         3  256622.714286           Banyak
# 3    Surabaya        2990         1  259528.714286          Sedikit
# 4       Medan      602155         2  339636.285714          Sedikit
# 5  Yogyakarta      466755         1  204236.285714          Sedikit
# 6      Malang      746755         2  484236.285714          Sedikit

# %%
group_mean = df.groupby('Kategori_Bandara')['Population'].mean()
print(group_mean)
# Out:
# Kategori_Bandara
# Banyak       5896.000000
# Sedikit    305289.166667
# Name: Population, dtype: float64

# %%
group_agg = df.groupby('Kategori_Bandara').agg({
    'Population': ['mean', 'max'],
    'Airports': ['mean', 'count']
})
group_agg
# Out:
#                      Population         Airports
#                            mean     max     mean count
# Kategori_Bandara
# Banyak              5896.000000    5896      3.0     1
# Sedikit           305289.166667  746755      1.5     6

# %%
import pandas as pd

body_measurement_df = pd.DataFrame.from_records((
    (2, 83.22, 8.4),
    (3, 99.31, 16.97),
    (3, 96.52, 14.21),
    (6, 114.3, 21.41),
    (6, 121.92, 21.86),
    (6, 86.36, 16.24),
    (7, 138.43, 25.56),
    (7, 141.73, 28.12),
    (2, 85.85, 14.18),
    (2, 86.26, 15.84),
    (9, 127.23, 13.27),
    (6, 159.26, 23.36),
    (4, 104.88, 14.78),
    (6, 115.60, 20.86),
    (7, 141.73, 27.84),
    (7, 121.92, 26.21),
    (3, 94.49, 15.45),
    (6, 116.59, 17.55),
    (7, 121.92, 22.96)
), columns=("age", "height_cm", "weight_kg"))

body_measurement_df
# Out:
#     age  height_cm  weight_kg
# 0     2      83.22       8.40
# 1     3      99.31      16.97
# 2     3      96.52      14.21
# 3     6     114.30      21.41
# 4     6     121.92      21.86
# 5     6      86.36      16.24
# 6     7     138.43      25.56
# 7     7     141.73      28.12
# 8     2      85.85      14.18
# 9     2      86.26      15.84
# 10    9     127.23      13.27
# 11    6     159.26      23.36
# 12    4     104.88      14.78
# 13    6     115.60      20.86
# 14    7     141.73      27.84
# 15    7     121.92      26.21
# 16    3      94.49      15.45
# 17    6     116.59      17.55
# 18    7     121.92      22.96

# %%
body_measurement_df.describe()
# Out:
#              age   height_cm  weight_kg
# count  19.000000   19.000000  19.000000
# mean    5.210526  113.553684  19.214211
# std     2.123387   22.123960   5.543822
# min     2.000000   83.220000   8.400000
# 25%     3.000000   95.505000  15.115000
# 50%     6.000000  115.600000  17.550000
# 75%     7.000000  124.575000  23.160000
# max     9.000000  159.260000  28.120000

# %%
mean_height = body_measurement_df["height_cm"].mean()
mean_weight = body_measurement_df["weight_kg"].mean()

print("Rata-rata tinggi:", mean_height)
print("Rata-rata berat:", mean_weight)
# Out:
# Rata-rata tinggi: 113.55368421052631
# Rata-rata berat: 19.214210526315785

# %%
mode_age = body_measurement_df["age"].mode()
print("Modus umur:", mode_age)
# Out:
# Modus umur: 0    6
# Name: age, dtype: int64

# %%
import matplotlib.pyplot as plt

# Tinggi
body_measurement_df['height_cm'].hist()
plt.title("Distribusi Tinggi Badan (cm)")
plt.show()

# Berat
body_measurement_df['weight_kg'].hist()
plt.title("Distribusi Berat Badan (kg)")
plt.show()

# %%
group_mean_age = body_measurement_df.groupby('age').mean()
group_mean_age
# Out:
#       height_cm  weight_kg
# age
# 2     85.110000  12.806667
# 3     96.773333  15.543333
# 4    104.880000  14.780000
# 6    119.005000  20.213333
# 7    133.146000  26.138000
# 9    127.230000  13.270000

# %%
group_Agg_age = body_measurement_df.groupby('age').agg({
    'height_cm': ['mean', 'min', 'max'],
    'weight_kg': ['mean', 'min', 'max']
})
group_Agg_age
# Out:
#       height_cm                  weight_kg
#            mean     min     max       mean    min    max
# age
# 2     85.110000   83.22   86.26  12.806667   8.40  15.84
# 3     96.773333   94.49   99.31  15.543333  14.21  16.97
# 4    104.880000  104.88  104.88  14.780000  14.78  14.78
# 6    119.005000   86.36  159.26  20.213333  16.24  23.36
# 7    133.146000  121.92  141.73  26.138000  22.96  28.12
# 9    127.230000  127.23  127.23  13.270000  13.27  13.27

# %%
# Korelasi
corr = body_measurement_df[['height_cm', 'weight_kg']].corr()
print(corr)

# Kovarian
cov = body_measurement_df[['height_cm', 'weight_kg']].cov()
print(cov)
# Out:
#            height_cm  weight_kg
# height_cm   1.000000   0.788091
# weight_kg   0.788091   1.000000
#             height_cm  weight_kg
# height_cm  489.469602  96.660417
# weight_kg   96.660417  30.733959
